# %% [markdown]
# <h1> 전반적인 프로세스는 다음과 같다. </h1>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * 내가 이해한게 맞은 것 같지만
# * 아닐 수도 있으니 내가 맞게 이해했는지 재확인하고자 한다.

# %% [markdown]
# <h1> 질문 </h1>

# %% [markdown]
# 1.  intent 번호에 따른 답변(A)이 똑같은 경우도 있고, 다른 경우도 있는데
#    똑같이 되어야 되지 않나 생각이 들었었습니다.
#
#    그니까 모델을 만들고, 어떤 질문이 들어오면 intent를 분류해서, 그에 따른 매핑되는 답변(A)를 print 해주는 것으로 이해했는데<br>
#    intent에 따른 답변(A)가 다르면, 어느 것을 print 해야 하는지 모르니까<br>
#    intent에 따른 답변(A)가 똑같이 있으면 그것을 바로 print 하면 되니까<br> 이에 대한 질문을 한 것 같습니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * 결국은 텍스트를 숫자 형태로 변환을 해야 하는데 효율적인 방법이 요구된다.
#   이를 수행하는 방법은 다양하다.<br> N-Gram, Sequence도 있고, Word2Vec도 있다.
